# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df['Age'].hist(bins = 20)#df['Age'].hist()
# Out:
# <Axes: >

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df = df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [183 rows x 12 columns]

# %%
df['Age'].mean()
# Out:
# np.float64(35.6744262295082)

# %%
df['Age'].median()
# Out:
# np.float64(36.0)

# %%
df['Age'].mode()
# Out:
# 0    36.0
# Name: Age, dtype: float64

# %%
df.index
# Out:
# Index([  1,   3,   6,  10,  11,  21,  23,  27,  52,  54,
#        ...
#        835, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#       dtype='int64', length=183)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 183 entries, 1 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  183 non-null    int64
#  1   Survived     183 non-null    int64
#  2   Pclass       183 non-null    int64
#  3   Name         183 non-null    object
#  4   Sex          183 non-null    object
#  5   Age          183 non-null    float64
#  6   SibSp        183 non-null    int64
#  7   Parch        183 non-null    int64
#  8   Ticket       183 non-null    object
#  9   Fare         183 non-null    float64
#  10  Cabin        183 non-null    object
#  11  Embarked     183 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 18.6+ KB

# %%
#series
age = df['Age']

# %%
age.values[5:10]
# Out:
# array([34., 28., 19., 49., 65.])

# %%
df['Age'].values[:10]
# Out:
# array([38., 35., 54.,  4., 58., 34., 28., 19., 49., 65.])

# %%
age = age*2
age
# Out:
# 1       76.0
# 3       70.0
# 6      108.0
# 10       8.0
# 11     116.0
#        ...
# 871     94.0
# 872     66.0
# 879    112.0
# 887     38.0
# 889     52.0
# Name: Age, Length: 183, dtype: float64

# %%
df['Age'].values[:10]
# Out:
# array([38., 35., 54.,  4., 58., 34., 28., 19., 49., 65.])

# %%
df[df['Sex'] == 'female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 11            12         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 3        0    113803  53.1000  C123        S
# 10       1   PP 9549  16.7000    G6        S
# 11       0    113783  26.5500  C103        S
# 52       0  PC 17572  76.7292   D33        C
# ..     ...       ...      ...   ...      ...
# 853      1  PC 17592  39.4000   D28        S
# 862      0     17466  25.9292   D17        S
# 871      1     11751  52.5542   D35        S
# 879      1     11767  83.1583   C50        C
# 887      0    112053  30.0000   B42        S
#
# [88 rows x 12 columns]

# %%
df[df['Sex'] == 'female'].count()
# Out:
# PassengerId    88
# Survived       88
# Pclass         88
# Name           88
# Sex            88
# Age            88
# SibSp          88
# Parch          88
# Ticket         88
# Fare           88
# Cabin          88
# Embarked       88
# dtype: int64

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                          Carlsson, Mr. Frans Olof    male  33.0      0
# 879     Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                      Graham, Miss. Margaret Edith  female  19.0      0
# 889                             Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch  Ticket     Fare        Cabin Embarked
# 871      1   11751  52.5542          D35        S
# 872      0     695   5.0000  B51 B53 B55        S
# 879      1   11767  83.1583          C50        C
# 887      0  112053  30.0000          B42        S
# 889      0  111369  30.0000         C148        C

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
df.count()
# Out:
# PassengerId    183
# Survived       183
# Pclass         183
# Name           183
# Sex            183
# Age            183
# SibSp          183
# Parch          183
# Ticket         183
# Fare           183
# Cabin          183
# Embarked       183
# dtype: int64

# %%
df.iloc[0:5,1:3]
# Out:
#     Survived  Pclass
# 1          1       1
# 3          1       1
# 6          0       1
# 10         1       3
# 11         1       1

# %%
df = df.set_index('Sex')

# %%
df.loc['female']
# Out:
#         PassengerId  Survived  Pclass  \
# Sex
# female            2         1       1
# female            4         1       1
# female           11         1       3
# female           12         1       1
# female           53         1       1
# ...             ...       ...     ...
# female          854         1       1
# female          863         1       1
# female          872         1       1
# female          880         1       1
# female          888         1       1
#
#                                                      Name   Age  SibSp  Parch  \
# Sex
# female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# female                    Sandstrom, Miss. Marguerite Rut   4.0      1      1
# female                           Bonnell, Miss. Elizabeth  58.0      0      0
# female           Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0      1      0
# ...                                                   ...   ...    ...    ...
# female                          Lines, Miss. Mary Conover  16.0      0      1
# female  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  48.0      0      0
# female   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0      1      1
# female      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0      0      1
# female                       Graham, Miss. Margaret Edith  19.0      0      0
#
#           Ticket     Fare Cabin Embarked
# Sex
# female  PC 17599  71.2833   C85        C
# female    113803  53.1000  C123        S
# female   PP 9549  16.7000    G6        S
# female    113783  26.5500  C103        S
# female  PC 17572  76.7292   D33        C
# ...          ...      ...   ...      ...
# female  PC 17592  39.4000   D28        S
# female     17466  25.9292   D17        S
# female     11751  52.5542   D35        S
# female     11767  83.1583   C50        C
# female    112053  30.0000   B42        S
#
# [88 rows x 11 columns]

# %%
df = df.set_index('PassengerId')

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 7                                      McCarthy, Mr. Timothy J  54.0      0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0      1
# 12                                    Bonnell, Miss. Elizabeth  58.0      0
# ...                                                        ...   ...    ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0      1
# 873                                   Carlsson, Mr. Frans Olof  33.0      0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0      0
# 888                               Graham, Miss. Margaret Edith  19.0      0
# 890                                      Behr, Mr. Karl Howell  26.0      0
#
#              Parch    Ticket     Fare        Cabin Embarked
# PassengerId
# 2                0  PC 17599  71.2833          C85        C
# 4                0    113803  53.1000         C123        S
# 7                0     17463  51.8625          E46        S
# 11               1   PP 9549  16.7000           G6        S
# 12               0    113783  26.5500         C103        S
# ...            ...       ...      ...          ...      ...
# 872              1     11751  52.5542          D35        S
# 873              0       695   5.0000  B51 B53 B55        S
# 880              1     11767  83.1583          C50        C
# 888              0    112053  30.0000          B42        S
# 890              0    111369  30.0000         C148        C
#
# [183 rows x 10 columns]

# %%
df.groupby('Pclass')['Survived'].sum()
# Out:
# Pclass
# 1    106
# 2     12
# 3      5
# Name: Survived, dtype: int64

# %%
res = df.groupby('Pclass')['Survived'].count()

# %%
res.values
# Out:
# array([158,  15,  10])

# %%
df.describe() # итоговая статистика для каждой колонки
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  183.000000  183.000000  183.000000  183.000000  183.000000  183.000000
# mean     0.672131    1.191257   35.674426    0.464481    0.475410   78.682469
# std      0.470725    0.515187   15.643866    0.644159    0.754617   76.347843
# min      0.000000    1.000000    0.920000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   24.000000    0.000000    0.000000   29.700000
# 50%      1.000000    1.000000   36.000000    0.000000    0.000000   57.000000
# 75%      1.000000    1.000000   47.500000    1.000000    1.000000   90.000000
# max      1.000000    3.000000   80.000000    3.000000    4.000000  512.329200

# %%
df['Age'].plot(kind='line') # kind = 'line', 'bar', 'hist', 'density', 'area', 'pie', 'scatter', 'hexbin'
# построить различные типы графиков
# Out:
# <Axes: xlabel='PassengerId'>

# %%
df['Age'].argmax()
# Out:
# np.int64(129)

# %%
df['Age'].max()
# Out:
# np.float64(80.0)

# %%
df['Age'].value_counts()
# Out:
# Age
# 36.0    11
# 24.0     9
# 19.0     6
# 35.0     6
# 49.0     5
#         ..
# 6.0      1
# 57.0     1
# 43.0     1
# 11.0     1
# 26.0     1
# Name: count, Length: 63, dtype: int64

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
df['Cabin'].isna().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 7                                      McCarthy, Mr. Timothy J  54.0      0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0      1
# 12                                    Bonnell, Miss. Elizabeth  58.0      0
# ...                                                        ...   ...    ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0      1
# 873                                   Carlsson, Mr. Frans Olof  33.0      0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0      0
# 888                               Graham, Miss. Margaret Edith  19.0      0
# 890                                      Behr, Mr. Karl Howell  26.0      0
#
#              Parch    Ticket     Fare        Cabin Embarked
# PassengerId
# 2                0  PC 17599  71.2833          C85        C
# 4                0    113803  53.1000         C123        S
# 7                0     17463  51.8625          E46        S
# 11               1   PP 9549  16.7000           G6        S
# 12               0    113783  26.5500         C103        S
# ...            ...       ...      ...          ...      ...
# 872              1     11751  52.5542          D35        S
# 873              0       695   5.0000  B51 B53 B55        S
# 880              1     11767  83.1583          C50        C
# 888              0    112053  30.0000          B42        S
# 890              0    111369  30.0000         C148        C
#
# [183 rows x 10 columns]

# %%
df.duplicated()
# Out:
# PassengerId
# 2      False
# 4      False
# 7      False
# 11     False
# 12     False
#        ...
# 872    False
# 873    False
# 880    False
# 888    False
# 890    False
# Length: 183, dtype: bool

# %%
df.drop_duplicates()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 7                                      McCarthy, Mr. Timothy J  54.0      0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0      1
# 12                                    Bonnell, Miss. Elizabeth  58.0      0
# ...                                                        ...   ...    ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0      1
# 873                                   Carlsson, Mr. Frans Olof  33.0      0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0      0
# 888                               Graham, Miss. Margaret Edith  19.0      0
# 890                                      Behr, Mr. Karl Howell  26.0      0
#
#              Parch    Ticket     Fare        Cabin Embarked
# PassengerId
# 2                0  PC 17599  71.2833          C85        C
# 4                0    113803  53.1000         C123        S
# 7                0     17463  51.8625          E46        S
# 11               1   PP 9549  16.7000           G6        S
# 12               0    113783  26.5500         C103        S
# ...            ...       ...      ...          ...      ...
# 872              1     11751  52.5542          D35        S
# 873              0       695   5.0000  B51 B53 B55        S
# 880              1     11767  83.1583          C50        C
# 888              0    112053  30.0000          B42        S
# 890              0    111369  30.0000         C148        C
#
# [183 rows x 10 columns]

# %%
df.dropna()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 11                  1       3
# 12                  1       1
# ...               ...     ...
# 872                 1       1
# 873                 0       1
# 880                 1       1
# 888                 1       1
# 890                 1       1
#
#                                                           Name   Age  SibSp  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1
# 7                                      McCarthy, Mr. Timothy J  54.0      0
# 11                             Sandstrom, Miss. Marguerite Rut   4.0      1
# 12                                    Bonnell, Miss. Elizabeth  58.0      0
# ...                                                        ...   ...    ...
# 872           Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0      1
# 873                                   Carlsson, Mr. Frans Olof  33.0      0
# 880              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0      0
# 888                               Graham, Miss. Margaret Edith  19.0      0
# 890                                      Behr, Mr. Karl Howell  26.0      0
#
#              Parch    Ticket     Fare        Cabin Embarked
# PassengerId
# 2                0  PC 17599  71.2833          C85        C
# 4                0    113803  53.1000         C123        S
# 7                0     17463  51.8625          E46        S
# 11               1   PP 9549  16.7000           G6        S
# 12               0    113783  26.5500         C103        S
# ...            ...       ...      ...          ...      ...
# 872              1     11751  52.5542          D35        S
# 873              0       695   5.0000  B51 B53 B55        S
# 880              1     11767  83.1583          C50        C
# 888              0    112053  30.0000          B42        S
# 890              0    111369  30.0000         C148        C
#
# [183 rows x 10 columns]

# %%
# разбейте исходную таблицу на 2: по полу пассажиров
# удалите пустые строки или заполните их соответствующими символами
# Построить гистограмму распределения пассажиров по возрасту
# Вычислите мин и макс, среднее, моду, медиану возраста пассажира каждого пола
# визуализировать возраст при помощи различных настроек метода plot

df = pd.read_csv('titanic.csv').dropna().drop_duplicates()

# %%
male_df = df[df['Sex'] == 'male']

male_df
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 21            22         1       2                 Beesley, Mr. Lawrence
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
# ..           ...       ...     ...                                   ...
# 806          807         0       1                Andrews, Mr. Thomas Jr
# 857          858         1       1                Daly, Mr. Peter Denis
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 889          890         1       1                 Behr, Mr. Karl Howell
#
#       Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 6    male  54.0      0      0     17463   51.8625          E46        S
# 21   male  34.0      0      0    248698   13.0000          D56        S
# 23   male  28.0      0      0    113788   35.5000           A6        S
# 27   male  19.0      3      2     19950  263.0000  C23 C25 C27        S
# 54   male  65.0      0      1    113509   61.9792          B30        C
# ..    ...   ...    ...    ...       ...       ...          ...      ...
# 806  male  39.0      0      0    112050    0.0000          A36        S
# 857  male  51.0      0      0    113055   26.5500          E17        S
# 867  male  31.0      0      0  PC 17590   50.4958          A24        S
# 872  male  33.0      0      0       695    5.0000  B51 B53 B55        S
# 889  male  26.0      0      0    111369   30.0000         C148        C
#
# [95 rows x 12 columns]

# %%
male_df['Age'].hist()
# Out:
# <Axes: >

# %%
print(male_df['Age'].describe())
print(f'mode: {male_df['Age'].mode()[0]}')
print(f'median: {male_df['Age'].median()}')
# Out:
# count    95.000000
# mean     38.451789
# std      16.429746
# min       0.920000
# 25%      28.000000
# 50%      37.000000
# 75%      49.000000
# max      80.000000
# Name: Age, dtype: float64
# mode: 36.0
# median: 37.0

# %%
female_df = df[df['Sex'] == 'female']

female_df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 10            11         1       3
# 11            12         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 853                          Lines, Miss. Mary Conover  female  16.0      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# 1        0  PC 17599  71.2833   C85        C
# 3        0    113803  53.1000  C123        S
# 10       1   PP 9549  16.7000    G6        S
# 11       0    113783  26.5500  C103        S
# 52       0  PC 17572  76.7292   D33        C
# ..     ...       ...      ...   ...      ...
# 853      1  PC 17592  39.4000   D28        S
# 862      0     17466  25.9292   D17        S
# 871      1     11751  52.5542   D35        S
# 879      1     11767  83.1583   C50        C
# 887      0    112053  30.0000   B42        S
#
# [88 rows x 12 columns]

# %%
female_df['Age'].hist()
# Out:
# <Axes: >

# %%
print(female_df['Age'].describe())
print(f'mode: {female_df['Age'].mode()[0]}')
print(f'median: {female_df['Age'].median()}')
# Out:
# count    88.000000
# mean     32.676136
# std      14.240552
# min       2.000000
# 25%      22.750000
# 50%      32.250000
# 75%      41.500000
# max      63.000000
# Name: Age, dtype: float64
# mode: 24.0
# median: 32.25

# %%
# изменение типов данных таблицы
# my_series = pd.to_numeric(my_series)
# s = s.astype(np.float16) # for series
#
# df.drop(columns=['col1', 'col2']) # drop columns
# df.drop([0, 1])# drop rows

# %%
df['Age'].quantile([0.25,0.75]) # квартили
# Out:
# 0.25    24.0
# 0.75    47.5
# Name: Age, dtype: float64

# %%
male_df['Age'].plot(kind='hist', bins=20, color='blue', label='Male')
female_df['Age'].plot(kind='hist', alpha=0.7, bins=20, color='red', label='Female')

plt.title('Hist')
plt.xlabel('Age')
plt.legend()
plt.show()

# %%
plt.scatter(male_df.index, male_df['Age'], alpha=0.7, color='blue', label='Male')
plt.scatter(female_df.index, female_df['Age'], alpha=0.7, color='red', label='Female')

plt.title('Scatter')
plt.ylabel('Age')    
plt.legend()
plt.show()

# %%
male_df['Age'].plot(kind='density', color='female', label='Male')
female_df['Age'].plot(kind='density', color='red', label='Female')

plt.title('None')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[196], line 1
# ----> 1 male_df['Age'].plot(kind='density', color='female', label='Male')
#       2 female_df['Age'].plot(kind='density', color='red', label='Female')
#       4 plt.title('None')
#
# File c:\Python312\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Python312\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Python312\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Python312\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:127, in HistPlot._make_plot(self, fig)
#     126 def _make_plot(self, fig: Figure) -> None:
# --> 127     colors = self._get_colors()
#     128     stacking_id = self._get_stacking_id()
#     130     # Re-create iterated data if `by` is assigned by users
#
# File c:\Python312\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1094, in MPLPlot._get_colors(self, num_colors, color_kwds)
#    1092 else:
#    1093     color = self.kwds.get(color_kwds)
# -> 1094 return get_standard_colors(
#    1095     num_colors=num_colors,
#    1096     colormap=self.colormap,
#    1097     color=color,
#    1098 )
#
# File c:\Python312\Lib\site-packages\pandas\plotting\_matplotlib\style.py:70, in get_standard_colors(num_colors, colormap, color_type, color)
#      67 if isinstance(color, dict):
#      68     return color
# ---> 70 colors = _derive_colors(
#      71     color=color,
#      72     colormap=colormap,
#      73     color_type=color_type,
#      74     num_colors=num_colors,
#      75 )
#      77 return list(_cycle_colors(colors, num_colors=num_colors))
#
# File c:\Python312\Lib\site-packages\pandas\plotting\_matplotlib\style.py:127, in _derive_colors(color, colormap, color_type, num_colors)
#     122     if colormap is not None:
#     123         warnings.warn(
#     124             "'color' and 'colormap' cannot be used simultaneously. Using 'color'",
#     125             stacklevel=find_stack_level(),
#     126         )
# --> 127     return _get_colors_from_color(color)
#     128 else:
#     129     return _get_colors_from_color_type(color_type, num_colors=num_colors)
#
# File c:\Python312\Lib\site-packages\pandas\plotting\_matplotlib\style.py:173, in _get_colors_from_color(color)
#     170     return [color]
#     172 color = cast(Collection[Color], color)
# --> 173 return list(_gen_list_of_colors_from_iterable(color))
#
# File c:\Python312\Lib\site-packages\pandas\plotting\_matplotlib\style.py:206, in _gen_list_of_colors_from_iterable(color)
#     204     yield x
#     205 else:
# --> 206     raise ValueError(f"Invalid color {x}")
#
# ValueError: Invalid color female
